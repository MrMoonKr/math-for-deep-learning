# %%
# !python --version
# Out:
# Python 3.12.0

# %%
# %pip --version
# Out:
# pip 25.3 from e:\M-Github-AI\math-for-deep-learning\.venv\Lib\site-packages\pip (python 3.12)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run ch01_01_python.py
# Out:
# pip 25.3 from e:\M-Github-AI\math-for-deep-learning\.venv\Lib\site-packages\pip (python 3.12)
